# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchi15/CNN-MobileNetV2-Cifar10/blob/master/CNN_Assignment_5_Design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tenorflow
# select tensorflow 2 in colab
# %tensorflow_version 2.x
import tensorflow as     tf
from   tensorflow import keras
# Out:
# TensorFlow 2.x selected.

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
# tensorflow datasets
import tensorflow_datasets as tfds

# %%
# additional libraries
import math
import numpy             as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# data
DATA_NUM_CLASSES        = 10
DATA_CHANNELS           = 3
DATA_ROWS               = 32
DATA_COLS               = 32
DATA_CROP_ROWS          = 28
DATA_CROP_COLS          = 28
DATA_MEAN               = np.array([[[125.30691805, 122.95039414, 113.86538318]]]) # CIFAR10
DATA_STD_DEV            = np.array([[[ 62.99321928,  62.08870764,  66.70489964]]]) # CIFAR10

# %%
# model
MODEL_LEVEL_0_BLOCKS    = 4
MODEL_LEVEL_1_BLOCKS    = 6
MODEL_LEVEL_2_BLOCKS    = 3

# %%
# training
TRAINING_BATCH_SIZE      = 32
TRAINING_SHUFFLE_BUFFER  = 5000
TRAINING_BN_MOMENTUM     = 0.99
TRAINING_BN_EPSILON      = 0.001
TRAINING_LR_MAX          = 0.001
# TRAINING_LR_SCALE        = 0.1
# TRAINING_LR_EPOCHS       = 2
TRAINING_LR_INIT_SCALE   = 0.01
TRAINING_LR_INIT_EPOCHS  = 5
TRAINING_LR_FINAL_SCALE  = 0.01
TRAINING_LR_FINAL_EPOCHS = 55

# %%
# training (derived)
TRAINING_NUM_EPOCHS = TRAINING_LR_INIT_EPOCHS + TRAINING_LR_FINAL_EPOCHS
TRAINING_LR_INIT    = TRAINING_LR_MAX*TRAINING_LR_INIT_SCALE
TRAINING_LR_FINAL   = TRAINING_LR_MAX*TRAINING_LR_FINAL_SCALE

# %%
# saving
SAVE_MODEL_PATH = './save/model/'
# !mkdir -p "$SAVE_MODEL_PATH"

# %%
# pre processing for training data
def pre_processing_train(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]
  
    # image is cast to float32, normalized, augmented and random cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_crop(image, size=[DATA_CROP_ROWS, DATA_CROP_COLS, 3])
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# pre processing for testing data
def pre_processing_test(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]

    # image is cast to float32, normalized, augmented and center cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.crop_to_bounding_box(image, (DATA_ROWS - DATA_CROP_ROWS) // 2, (DATA_COLS - DATA_CROP_COLS) // 2, DATA_CROP_ROWS, DATA_CROP_COLS)
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# download data and split into training and testing datasets
dataset_train, info = tfds.load("cifar10", split=tfds.Split.TRAIN, with_info=True)
dataset_test,  info = tfds.load("cifar10", split=tfds.Split.TEST,  with_info=True)
dataset_train_np = tfds.as_numpy(dataset_train)
dataset_test_np = tfds.as_numpy(dataset_test)
# Out:
# Downloading and preparing dataset cifar10 (162.17 MiB) to /root/tensorflow_datasets/cifar10/3.0.0...
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Completed...', max=1, style=ProgressStyl…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Size...', max=1, style=ProgressStyle(des…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Extraction completed...', max=1, style=Prog…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteZ80LBC/cifar10-train.tfrecord
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteZ80LBC/cifar10-test.tfrecord
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.0. Subsequent calls will reuse this data.

# %%
# transform training dataset
dataset_train = dataset_train.map(pre_processing_train, num_parallel_calls=4)
dataset_train = dataset_train.shuffle(buffer_size=TRAINING_SHUFFLE_BUFFER)
dataset_train = dataset_train.batch(TRAINING_BATCH_SIZE)
dataset_train = dataset_train.prefetch(buffer_size=1)

# %%
# transform testing dataset
dataset_test = dataset_test.map(pre_processing_test, num_parallel_calls=4)
dataset_test = dataset_test.batch(TRAINING_BATCH_SIZE)
dataset_test = dataset_test.prefetch(buffer_size=1)

# %%
import os
import warnings
import numpy as np
from tensorflow.keras.layers import Input, Activation, Conv2D, Dense, Dropout, BatchNormalization, ReLU, DepthwiseConv2D, GlobalAveragePooling2D, GlobalMaxPooling2D, Add
from tensorflow.keras.models import Model
from keras import regularizers
# define the filter size
def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v



# define the calculation of each 'inverted Res_Block'
def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id):
    prefix = 'block_{}_'.format(block_id)

    in_channels = inputs.shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs

    # Expand
    if block_id:
        x = Conv2D(expansion * in_channels, kernel_size=1, strides=1, padding='same', use_bias=False, activation=None, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(4e-5), name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=prefix + 'expand_BN')(x)
        x = ReLU(6., name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'

    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None, use_bias=False, padding='same', kernel_initializer="he_normal", depthwise_regularizer=regularizers.l2(4e-5), name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=prefix + 'depthwise_BN')(x)
    x = ReLU(6., name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters, kernel_size=1, strides=1, padding='same', use_bias=False, activation=None, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(4e-5), name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name=prefix + 'project_BN')(x)


    if in_channels == pointwise_filters and stride == 1:
        return Add(name=prefix + 'add')([inputs, x])
    return x

#Create Build
def create_model(rows, cols, channels, level_0_blocks, level_1_blocks, level_2_blocks, num_classes, lr_initial):
  # encoder - input
    alpha=1.0
    include_top = True
    model_input = keras.Input(shape=(rows, cols, channels), name='input_image')
    x           = model_input

    first_block_filters = _make_divisible(32 * alpha, 8)

    # model architechture
    x = Conv2D(first_block_filters, kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(4e-5), name='Conv1')(model_input)

    x = _inverted_res_block(x, filters=16,  alpha=alpha, stride=1, expansion=1, block_id=0 )

    x = _inverted_res_block(x, filters=24,  alpha=alpha, stride=1, expansion=6, block_id=1 )
    x = _inverted_res_block(x, filters=24,  alpha=alpha, stride=1, expansion=6, block_id=2 )

    x = _inverted_res_block(x, filters=32,  alpha=alpha, stride=2, expansion=6, block_id=3 )
    x = _inverted_res_block(x, filters=32,  alpha=alpha, stride=1, expansion=6, block_id=4 )
    x = _inverted_res_block(x, filters=32,  alpha=alpha, stride=1, expansion=6, block_id=5 )

    x = _inverted_res_block(x, filters=64,  alpha=alpha, stride=2, expansion=6, block_id=6 )
    x = _inverted_res_block(x, filters=64,  alpha=alpha, stride=1, expansion=6, block_id=7 )
    x = _inverted_res_block(x, filters=64,  alpha=alpha, stride=1, expansion=6, block_id=8 )
    x = _inverted_res_block(x, filters=64,  alpha=alpha, stride=1, expansion=6, block_id=9 )
    x = Dropout(rate=0.25)(x)

    x = _inverted_res_block(x, filters=96,  alpha=alpha, stride=1, expansion=6, block_id=10)
    x = _inverted_res_block(x, filters=96,  alpha=alpha, stride=1, expansion=6, block_id=11)
    x = _inverted_res_block(x, filters=96,  alpha=alpha, stride=1, expansion=6, block_id=12)
    x = Dropout(rate=0.25)(x)

    x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, expansion=6, block_id=13)
    x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, expansion=6, block_id=14)
    x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, expansion=6, block_id=15)
    x = Dropout(rate=0.25)(x)

    x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, expansion=6, block_id=16)
    x = Dropout(rate=0.25)(x)


    # define filter size (last block)
    if alpha > 1.0:
        last_block_filters = _make_divisible(1280 * alpha, 8)
    else:
        last_block_filters = 1280


    x = Conv2D(last_block_filters, kernel_size=1, use_bias=False, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(4e-5), name='Conv_1')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999, name='Conv_1_bn')(x)
    x = ReLU(6., name='out_relu')(x)
    
    if include_top:
        x = GlobalAveragePooling2D(name='global_average_pool')(x)
        x = Dense(DATA_NUM_CLASSES, activation='softmax', use_bias=True, name='Logits')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    # create model of MobileNetV2 (for CIFAR-10)
    model = Model(inputs=model_input, outputs=x, name='mobilenetv2_cifar10')

    #model.compile(optimizer=tf.keras.optimizers.Adam(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=tf.keras.optimizers.Adam(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model
# Out:
# Using TensorFlow backend.

# %%
import os
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, CSVLogger, LearningRateScheduler
from datetime import datetime
model_name      = 'mobilenet_v2-like__' + datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

# build model
# create and compile model
model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, 
                     MODEL_LEVEL_0_BLOCKS, MODEL_LEVEL_1_BLOCKS, MODEL_LEVEL_2_BLOCKS, 
                     DATA_NUM_CLASSES, TRAINING_LR_MAX)
model.summary()
keras.utils.plot_model(model, 'cifar_model.png', show_shapes=True)

def lr_schedule(epoch):
    # staircase
    # lr = TRAINING_LR_MAX*math.pow(TRAINING_LR_SCALE, math.floor(epoch/TRAINING_LR_EPOCHS))
    # linear warmup followed by cosine decay
    if epoch < TRAINING_LR_INIT_EPOCHS:
        lr = (TRAINING_LR_MAX - TRAINING_LR_INIT)*(float(epoch)/TRAINING_LR_INIT_EPOCHS) + TRAINING_LR_INIT
    else:
        lr = (TRAINING_LR_MAX - TRAINING_LR_FINAL)
        #max(0.0, math.cos(((float(epoch) - TRAINING_LR_INIT_EPOCHS)/(TRAINING_LR_FINAL_EPOCHS - 1.0))(math.pi/2.0))) + TRAINING_LR_FINAL
    # debug - learning rate display
    # print(epoch)
    # print(lr)
    return lr

# plot training accuracy and loss curves
def plot_training_curves(history):

    # training and validation data accuracy
    acc     = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # training and validation data loss
    loss     = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()), 1])
    plt.title('Training and Validation Accuracy')

    # plot loss
    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0, 2.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule),
             keras.callbacks.ModelCheckpoint(filepath=SAVE_MODEL_PATH+'model_{epoch}.h5', save_best_only=True, monitor='val_loss', verbose=1)]
#compile & learning model

initial_epoch_num = 0
history = model.fit(x=dataset_train,
                epochs=60,
                verbose=1, 
                callbacks=callbacks, 
                validation_data=dataset_test,
                initial_epoch=initial_epoch_num)

plot_training_curves(history)
# test

test_loss, test_accuracy = model.evaluate(x=dataset_test)
print('Test loss:     ', test_loss)
print('Test accuracy: ', test_accuracy)

# extract a batch from the testing dataset then extract images and labels for this batch

# dataset_display                = dataset_test.take(1)
# it                             = iter(dataset_display)
# display_images, display_labels = next(it)



# # predict pmf and labels for this dataset

# predict_labels_pmf = model.predict(x=dataset_display)

# predict_labels     = np.argmax(predict_labels_pmf, axis=1)

# # for display normalize images to [0, 1]

# display_images = ((display_images*DATA_STD_DEV.reshape((1, 1, 1, 3))) + DATA_MEAN.reshape((1, 1, 1, 3)))/255.0;

# # cycle through the images in the batch

# for image_index in range(predict_labels.size):
#     # display the predicted label, actual label and image
#     print('Predicted label: {0:1d} and actual label: {1:1d}'.format(predict_labels[image_index], display_labels[image_index]))
#     plt.imshow(display_images[image_index, :, :, :])
#     plt.show()


# # save model "INSTANCE"
# f1_name = model_name + '_instance'
# f1_path = os.path.join(log_dir, f1_name) + '.h5'
# model.save(f1_path)

# # save model "WEIGHTs"
# f2_name = model_name + '_weights'
# f2_path = os.path.join(log_dir, f2_name) + '.h5'
# model.save_weights(f2_path)

# # save model "ARCHITECHTURE"
# f3_name = model_name + '_architechture'
# f3_path = os.path.join(log_dir, f3_name) + '.json'
# json_string = model.to_json()
# with open(f3_path, 'w') as f:
#     f.write(json_string)

# # save plot figure
# save_plot_log(log_dir, model_csv_path, index='acc')
# Out:
# Model: "mobilenetv2_cifar10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 28, 28, 32)   864         input_image[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 28, 28, 32)   288         Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 28, 28, 32)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 28, 28, 32)   0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 28, 28, 16)   512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 28, 28, 16)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 28, 28, 96)   1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 28, 28, 96)   384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 28, 28, 96)   0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 28, 28, 96)   864         block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 28, 28, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 28, 28, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 28, 28, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 28, 28, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 28, 28, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 28, 28, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 28, 28, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 28, 28, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 28, 28, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 28, 28, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 28, 28, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 28, 28, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 28, 28, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 14, 14, 144)  1296        block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 14, 14, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 14, 14, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 14, 14, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 14, 14, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 14, 14, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 14, 14, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 14, 14, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 14, 14, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 14, 14, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 14, 14, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 14, 14, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 14, 14, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 14, 14, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 14, 14, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 14, 14, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 14, 14, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 14, 14, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 14, 14, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 14, 14, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 7, 7, 192)    1728        block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 7, 7, 192)    768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 7, 7, 192)    0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 7, 7, 64)     12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 7, 7, 64)     256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 7, 7, 384)    24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 7, 7, 384)    1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 7, 7, 384)    0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 7, 7, 384)    3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 7, 7, 384)    1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 7, 7, 384)    0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 7, 7, 64)     24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 7, 7, 64)     256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 7, 7, 64)     0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 7, 7, 384)    24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 7, 7, 384)    1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 7, 7, 384)    0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 7, 7, 384)    3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 7, 7, 384)    1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 7, 7, 384)    0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 7, 7, 64)     24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 7, 7, 64)     256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 7, 7, 64)     0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 7, 7, 384)    24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 7, 7, 384)    1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 7, 7, 384)    0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 7, 7, 384)    3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 7, 7, 384)    1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 7, 7, 384)    0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 7, 7, 64)     24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 7, 7, 64)     256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 7, 7, 64)     0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 64)     0           block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 7, 7, 384)    24576       dropout[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 7, 7, 384)    1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 7, 7, 384)    0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 7, 7, 384)    3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 7, 7, 384)    1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 7, 7, 384)    0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 7, 7, 96)     36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 7, 7, 96)     384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 7, 7, 576)    55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 7, 7, 576)    2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 7, 7, 576)    0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 7, 7, 96)     55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 7, 7, 96)     384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 7, 7, 96)     0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 7, 7, 576)    55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 7, 7, 576)    2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 7, 7, 576)    0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 7, 7, 96)     55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 7, 7, 96)     384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 7, 7, 96)     0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 96)     0           block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 7, 7, 576)    55296       dropout_1[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 7, 7, 576)    2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 7, 7, 576)    0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 7, 7, 160)    0           block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      dropout_2[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 7, 7, 320)    0           block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      dropout_3[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pool (GlobalAver (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# Logits (Dense)                  (None, 10)           12810       global_average_pool[0][0]
# ==================================================================================================
# Total params: 2,270,666
# Trainable params: 2,236,618
# Non-trainable params: 34,048
# __________________________________________________________________________________________________
# Epoch 1/60
#    1563/Unknown - 70s 44ms/step - loss: 2.9610 - accuracy: 0.1799
# Epoch 00001: val_loss improved from inf to 3.18909, saving model to ./save/model/model_1.h5
# 1563/1563 [==============================] - 76s 48ms/step - loss: 2.9610 - accuracy: 0.1799 - val_loss: 3.1891 - val_accuracy: 0.1000
# Epoch 2/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.4838 - accuracy: 0.3618
# Epoch 00002: val_loss did not improve from 3.18909
# 1563/1563 [==============================] - 62s 40ms/step - loss: 2.4837 - accuracy: 0.3618 - val_loss: 3.5127 - val_accuracy: 0.1000
# Epoch 3/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.1541 - accuracy: 0.4844
# Epoch 00003: val_loss did not improve from 3.18909
# 1563/1563 [==============================] - 62s 40ms/step - loss: 2.1542 - accuracy: 0.4844 - val_loss: 3.6241 - val_accuracy: 0.1044
# Epoch 4/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.8217 - accuracy: 0.5827
# Epoch 00004: val_loss improved from 3.18909 to 1.91007, saving model to ./save/model/model_4.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 1.8213 - accuracy: 0.5830 - val_loss: 1.9101 - val_accuracy: 0.5752
# Epoch 5/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.5411 - accuracy: 0.6493
# Epoch 00005: val_loss did not improve from 1.91007
# 1563/1563 [==============================] - 63s 40ms/step - loss: 1.5410 - accuracy: 0.6493 - val_loss: 4.2912 - val_accuracy: 0.3918
# Epoch 6/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.3297 - accuracy: 0.6923
# Epoch 00006: val_loss did not improve from 1.91007
# 1563/1563 [==============================] - 62s 40ms/step - loss: 1.3298 - accuracy: 0.6923 - val_loss: 5.3494 - val_accuracy: 0.3161
# Epoch 7/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.1654 - accuracy: 0.7295
# Epoch 00007: val_loss did not improve from 1.91007
# 1563/1563 [==============================] - 63s 40ms/step - loss: 1.1654 - accuracy: 0.7295 - val_loss: 2.7852 - val_accuracy: 0.5203
# Epoch 8/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.0617 - accuracy: 0.7511
# Epoch 00008: val_loss improved from 1.91007 to 1.68328, saving model to ./save/model/model_8.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 1.0614 - accuracy: 0.7512 - val_loss: 1.6833 - val_accuracy: 0.6466
# Epoch 9/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.9853 - accuracy: 0.7696
# Epoch 00009: val_loss improved from 1.68328 to 1.17128, saving model to ./save/model/model_9.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.9857 - accuracy: 0.7696 - val_loss: 1.1713 - val_accuracy: 0.7344
# Epoch 10/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.9252 - accuracy: 0.7833
# Epoch 00010: val_loss did not improve from 1.17128
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.9254 - accuracy: 0.7832 - val_loss: 1.4575 - val_accuracy: 0.6470
# Epoch 11/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.8772 - accuracy: 0.7961
# Epoch 00011: val_loss improved from 1.17128 to 1.13377, saving model to ./save/model/model_11.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.8770 - accuracy: 0.7962 - val_loss: 1.1338 - val_accuracy: 0.7143
# Epoch 12/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.8434 - accuracy: 0.8025
# Epoch 00012: val_loss improved from 1.13377 to 0.94022, saving model to ./save/model/model_12.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.8433 - accuracy: 0.8025 - val_loss: 0.9402 - val_accuracy: 0.7812
# Epoch 13/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.8045 - accuracy: 0.8144
# Epoch 00013: val_loss did not improve from 0.94022
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.8050 - accuracy: 0.8143 - val_loss: 1.0937 - val_accuracy: 0.7495
# Epoch 14/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7814 - accuracy: 0.8223
# Epoch 00014: val_loss improved from 0.94022 to 0.89535, saving model to ./save/model/model_14.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.7814 - accuracy: 0.8222 - val_loss: 0.8954 - val_accuracy: 0.7892
# Epoch 15/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7510 - accuracy: 0.8291
# Epoch 00015: val_loss did not improve from 0.89535
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.7510 - accuracy: 0.8291 - val_loss: 1.1879 - val_accuracy: 0.7271
# Epoch 16/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7323 - accuracy: 0.8339
# Epoch 00016: val_loss did not improve from 0.89535
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.7322 - accuracy: 0.8340 - val_loss: 0.9198 - val_accuracy: 0.7857
# Epoch 17/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.8412
# Epoch 00017: val_loss did not improve from 0.89535
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.7111 - accuracy: 0.8413 - val_loss: 0.9630 - val_accuracy: 0.7613
# Epoch 18/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6964 - accuracy: 0.8441
# Epoch 00018: val_loss improved from 0.89535 to 0.77456, saving model to ./save/model/model_18.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6967 - accuracy: 0.8440 - val_loss: 0.7746 - val_accuracy: 0.8150
# Epoch 19/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6758 - accuracy: 0.8510
# Epoch 00019: val_loss did not improve from 0.77456
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6759 - accuracy: 0.8509 - val_loss: 0.8337 - val_accuracy: 0.8020
# Epoch 20/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6685 - accuracy: 0.8531
# Epoch 00020: val_loss improved from 0.77456 to 0.70603, saving model to ./save/model/model_20.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6681 - accuracy: 0.8531 - val_loss: 0.7060 - val_accuracy: 0.8417
# Epoch 21/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6548 - accuracy: 0.8555
# Epoch 00021: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6548 - accuracy: 0.8555 - val_loss: 0.8904 - val_accuracy: 0.7954
# Epoch 22/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6433 - accuracy: 0.8590
# Epoch 00022: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6431 - accuracy: 0.8590 - val_loss: 0.8811 - val_accuracy: 0.7946
# Epoch 23/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6318 - accuracy: 0.8619
# Epoch 00023: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6321 - accuracy: 0.8619 - val_loss: 0.7257 - val_accuracy: 0.8325
# Epoch 24/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6234 - accuracy: 0.8644
# Epoch 00024: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6236 - accuracy: 0.8644 - val_loss: 0.7375 - val_accuracy: 0.8369
# Epoch 25/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6080 - accuracy: 0.8707
# Epoch 00025: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.6078 - accuracy: 0.8707 - val_loss: 0.7608 - val_accuracy: 0.8286
# Epoch 26/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.8705
# Epoch 00026: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.6050 - accuracy: 0.8704 - val_loss: 0.7237 - val_accuracy: 0.8389
# Epoch 27/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6012 - accuracy: 0.8699
# Epoch 00027: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6014 - accuracy: 0.8699 - val_loss: 0.7102 - val_accuracy: 0.8407
# Epoch 28/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5879 - accuracy: 0.8747
# Epoch 00028: val_loss did not improve from 0.70603
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5879 - accuracy: 0.8747 - val_loss: 0.7773 - val_accuracy: 0.8161
# Epoch 29/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5846 - accuracy: 0.8765
# Epoch 00029: val_loss improved from 0.70603 to 0.69309, saving model to ./save/model/model_29.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5847 - accuracy: 0.8765 - val_loss: 0.6931 - val_accuracy: 0.8440
# Epoch 30/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5804 - accuracy: 0.8777
# Epoch 00030: val_loss did not improve from 0.69309
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5808 - accuracy: 0.8776 - val_loss: 0.7328 - val_accuracy: 0.8379
# Epoch 31/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5708 - accuracy: 0.8786
# Epoch 00031: val_loss improved from 0.69309 to 0.66307, saving model to ./save/model/model_31.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5707 - accuracy: 0.8786 - val_loss: 0.6631 - val_accuracy: 0.8553
# Epoch 32/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5647 - accuracy: 0.8817
# Epoch 00032: val_loss improved from 0.66307 to 0.65404, saving model to ./save/model/model_32.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5648 - accuracy: 0.8816 - val_loss: 0.6540 - val_accuracy: 0.8507
# Epoch 33/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5615 - accuracy: 0.8818
# Epoch 00033: val_loss did not improve from 0.65404
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5614 - accuracy: 0.8818 - val_loss: 0.7416 - val_accuracy: 0.8356
# Epoch 34/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5560 - accuracy: 0.8839
# Epoch 00034: val_loss improved from 0.65404 to 0.64882, saving model to ./save/model/model_34.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5562 - accuracy: 0.8838 - val_loss: 0.6488 - val_accuracy: 0.8592
# Epoch 35/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5499 - accuracy: 0.8840
# Epoch 00035: val_loss did not improve from 0.64882
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5500 - accuracy: 0.8840 - val_loss: 0.6505 - val_accuracy: 0.8617
# Epoch 36/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5462 - accuracy: 0.8872
# Epoch 00036: val_loss improved from 0.64882 to 0.59769, saving model to ./save/model/model_36.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5461 - accuracy: 0.8873 - val_loss: 0.5977 - val_accuracy: 0.8736
# Epoch 37/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.8875
# Epoch 00037: val_loss did not improve from 0.59769
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5409 - accuracy: 0.8874 - val_loss: 0.7299 - val_accuracy: 0.8313
# Epoch 38/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.8891
# Epoch 00038: val_loss did not improve from 0.59769
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5395 - accuracy: 0.8891 - val_loss: 0.6564 - val_accuracy: 0.8559
# Epoch 39/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5343 - accuracy: 0.8889
# Epoch 00039: val_loss improved from 0.59769 to 0.59367, saving model to ./save/model/model_39.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5344 - accuracy: 0.8889 - val_loss: 0.5937 - val_accuracy: 0.8737
# Epoch 40/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5293 - accuracy: 0.8904
# Epoch 00040: val_loss did not improve from 0.59367
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5293 - accuracy: 0.8904 - val_loss: 0.6863 - val_accuracy: 0.8482
# Epoch 41/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5239 - accuracy: 0.8920
# Epoch 00041: val_loss did not improve from 0.59367
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5239 - accuracy: 0.8920 - val_loss: 0.6000 - val_accuracy: 0.8686
# Epoch 42/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5279 - accuracy: 0.8927
# Epoch 00042: val_loss did not improve from 0.59367
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5277 - accuracy: 0.8927 - val_loss: 0.5971 - val_accuracy: 0.8709
# Epoch 43/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5133 - accuracy: 0.8968
# Epoch 00043: val_loss did not improve from 0.59367
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5134 - accuracy: 0.8968 - val_loss: 0.6229 - val_accuracy: 0.8631
# Epoch 44/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5154 - accuracy: 0.8943
# Epoch 00044: val_loss improved from 0.59367 to 0.58333, saving model to ./save/model/model_44.h5
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5153 - accuracy: 0.8943 - val_loss: 0.5833 - val_accuracy: 0.8718
# Epoch 45/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5131 - accuracy: 0.8966
# Epoch 00045: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.5134 - accuracy: 0.8966 - val_loss: 0.6859 - val_accuracy: 0.8452
# Epoch 46/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5082 - accuracy: 0.8971
# Epoch 00046: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5083 - accuracy: 0.8971 - val_loss: 0.6616 - val_accuracy: 0.8577
# Epoch 47/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5063 - accuracy: 0.8977
# Epoch 00047: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5062 - accuracy: 0.8977 - val_loss: 0.6404 - val_accuracy: 0.8592
# Epoch 48/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5063 - accuracy: 0.8977
# Epoch 00048: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5061 - accuracy: 0.8977 - val_loss: 0.6176 - val_accuracy: 0.8730
# Epoch 49/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5041 - accuracy: 0.8988
# Epoch 00049: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5040 - accuracy: 0.8988 - val_loss: 0.6193 - val_accuracy: 0.8683
# Epoch 50/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4983 - accuracy: 0.8997
# Epoch 00050: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4982 - accuracy: 0.8997 - val_loss: 0.6561 - val_accuracy: 0.8563
# Epoch 51/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4941 - accuracy: 0.9029
# Epoch 00051: val_loss did not improve from 0.58333
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.4943 - accuracy: 0.9029 - val_loss: 0.6250 - val_accuracy: 0.8627
# Epoch 52/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4919 - accuracy: 0.9028
# Epoch 00052: val_loss improved from 0.58333 to 0.57901, saving model to ./save/model/model_52.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4920 - accuracy: 0.9028 - val_loss: 0.5790 - val_accuracy: 0.8803
# Epoch 53/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4925 - accuracy: 0.9036
# Epoch 00053: val_loss did not improve from 0.57901
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.4924 - accuracy: 0.9037 - val_loss: 0.5794 - val_accuracy: 0.8777
# Epoch 54/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4890 - accuracy: 0.9041
# Epoch 00054: val_loss did not improve from 0.57901
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4889 - accuracy: 0.9042 - val_loss: 0.6200 - val_accuracy: 0.8663
# Epoch 55/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4854 - accuracy: 0.9049
# Epoch 00055: val_loss did not improve from 0.57901
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.4853 - accuracy: 0.9050 - val_loss: 0.6044 - val_accuracy: 0.8731
# Epoch 56/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4824 - accuracy: 0.9053
# Epoch 00056: val_loss improved from 0.57901 to 0.56233, saving model to ./save/model/model_56.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4824 - accuracy: 0.9054 - val_loss: 0.5623 - val_accuracy: 0.8835
# Epoch 57/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4824 - accuracy: 0.9065
# Epoch 00057: val_loss improved from 0.56233 to 0.55509, saving model to ./save/model/model_57.h5
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4824 - accuracy: 0.9065 - val_loss: 0.5551 - val_accuracy: 0.8868
# Epoch 58/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4750 - accuracy: 0.9090
# Epoch 00058: val_loss did not improve from 0.55509
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.4750 - accuracy: 0.9090 - val_loss: 0.6370 - val_accuracy: 0.8667
# Epoch 59/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4782 - accuracy: 0.9078
# Epoch 00059: val_loss did not improve from 0.55509
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.4784 - accuracy: 0.9077 - val_loss: 0.5910 - val_accuracy: 0.8715
# Epoch 60/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4733 - accuracy: 0.9081
# Epoch 00060: val_loss did not improve from 0.55509
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.4731 - accuracy: 0.9081 - val_loss: 0.6343 - val_accuracy: 0.8631
#     313/Unknown - 6s 18ms/step - loss: 0.6343 - accuracy: 0.8631Test loss:      0.6342947885822564
# Test accuracy:  0.8631
